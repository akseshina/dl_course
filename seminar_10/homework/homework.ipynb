# %% [markdown]
# ## Homework: Deep Jazz

# %%
import numpy as np
from music21 import stream, midi, tempo, note

from grammar import unparse_grammar
from preprocess import get_musical_data, get_corpus_data

from qa import prune_grammar, prune_notes, clean_up_notes
from generator import __sample, __generate_grammar, __predict

# %%
import tflearn

# %%
N_epochs = 128  # default
data_fn = 'midi/' + 'original_metheny.mid'  # 'And Then I Knew' by Pat Metheny
out_fn = 'midi/' 'deepjazz_on_metheny...' + str(N_epochs)

# %%
max_len = 20
max_tries = 1000
diversity = 0.5

# musical settings
bpm = 130

# get data
chords, abstract_grammars = get_musical_data(data_fn)
corpus, values, val_indices, indices_val = get_corpus_data(abstract_grammars)
print('corpus length:', len(corpus))
print('total # of values:', len(values))
# Out:
# corpus length: 193
# total # of values: 78

# %%
chords[0]
# Out:
# [<music21.instrument.Piano Piano>,
#  <music21.tempo.MetronomeMark Quarter=112.0>,
#  <music21.key.Key of G major>,
#  <music21.meter.TimeSignature 4/4>]

# %%
def get_keras_model(max_len, N_values):
    # build a 2 stacked LSTM
    model = Sequential()
    model.add(LSTM(128, return_sequences=True, input_shape=(max_len, N_values)))
    model.add(Dropout(0.2))
    model.add(LSTM(128, return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(N_values))
    model.add(Activation('softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='rmsprop')
    return model

# %% [markdown]
# ## Task

# %% [markdown]
# Replace previous model with equivalent in prettytensor or tf.slim
#
# Try to make you code as compact as possible

# %%
from tflearn import input_data, lstm, fully_connected, regression, dropout, activation

def get_tflearn_model(max_len, N_values):
    
    # Network building
    net = input_data([None, max_len, N_values])
    net = lstm(net, 128, return_seq=True)
    net = dropout(net, 0.2)
    net = tflearn.lstm(net, 128, return_seq=False)
    net = dropout(net, 0.2)
    net = fully_connected(net, N_values)
    net = activation(net, activation='softmax')
    net = tflearn.regression(net, loss='categorical_crossentropy', optimizer='rmsprop')
    
    # Training
    model = tflearn.DNN(net, tensorboard_dir='tflearn_log')
    
    return model

# %%
get_model = get_tflearn_model

# %%
import numpy as np

''' Build a 2-layer LSTM from a training corpus '''


def build_model(corpus, val_indices, max_len, N_epochs=128):
    # number of different values or words in corpus
    N_values = len(set(corpus))

    # cut the corpus into semi-redundant sequences of max_len values
    step = 3
    sentences = []
    next_values = []
    for i in range(0, len(corpus) - max_len, step):
        sentences.append(corpus[i: i + max_len])
        next_values.append(corpus[i + max_len])
    print('nb sequences:', len(sentences))

    # transform data into binary matrices
    X = np.zeros((len(sentences), max_len, N_values), dtype=np.bool)
    y = np.zeros((len(sentences), N_values), dtype=np.bool)
    for i, sentence in enumerate(sentences):
        for t, val in enumerate(sentence):
            X[i, t, val_indices[val]] = 1
        y[i, val_indices[next_values[i]]] = 1

    model = get_model(max_len, N_values)
    model.fit(X, y, batch_size=128, n_epoch=N_epochs)

    return model

# %%
import tensorflow as tf
tf.reset_default_graph()

# %%
# build model
model = build_model(corpus=corpus, val_indices=val_indices,
                         max_len=max_len, N_epochs=N_epochs)

# set up audio stream
out_stream = stream.Stream()

# generation loop
curr_offset = 0.0
loopEnd = len(chords)
for loopIndex in range(1, loopEnd):
    # get chords from file
    curr_chords = stream.Voice()
    for j in chords[loopIndex]:
        curr_chords.insert((j.offset % 4), j)

    # generate grammar
    curr_grammar = __generate_grammar(model=model, corpus=corpus,
                                      abstract_grammars=abstract_grammars,
                                      values=values, val_indices=val_indices,
                                      indices_val=indices_val,
                                      max_len=max_len, max_tries=max_tries,
                                      diversity=diversity)

    curr_grammar = curr_grammar.replace(' A', ' C').replace(' X', ' C')

    # Pruning #1: smoothing measure
    curr_grammar = prune_grammar(curr_grammar)

    # Get notes from grammar and chords
    curr_notes = unparse_grammar(curr_grammar, curr_chords)

    # Pruning #2: removing repeated and too close together notes
    curr_notes = prune_notes(curr_notes)

    # quality assurance: clean up notes
    curr_notes = clean_up_notes(curr_notes)

    # print # of notes in curr_notes
    print('After pruning: %s notes' % (len([i for i in curr_notes
                                            if isinstance(i, note.Note)])))

    # insert into the output stream
    for m in curr_notes:
        out_stream.insert(curr_offset + m.offset, m)
    for mc in curr_chords:
        out_stream.insert(curr_offset + mc.offset, mc)

    curr_offset += 4.0

out_stream.insert(0.0, tempo.MetronomeMark(number=bpm))

# Play the final stream through output (see 'play' lambda function above)
# play = lambda x: midi.realtime.StreamPlayer(x).play()
# play(out_stream)

# save stream
mf = midi.translate.streamToMidiFile(out_stream)
mf.open(out_fn, 'wb')
mf.write()
mf.close()
# Out:
# nb sequences: 58
# ---------------------------------
# Run id: W9XXQJ
# Log directory: tflearn_log/
# WARNING:tensorflow:Error encountered when serializing layer_tensor/LSTM.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'list' object has no attribute 'name'
# WARNING:tensorflow:Error encountered when serializing layer_tensor/Dropout.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'list' object has no attribute 'name'
# ---------------------------------
# Training samples: 58
# Validation samples: 0
# --
# Training Step: 1  | time: 0.290s
# | RMSProp | epoch: 001 | loss: 0.00000 -- iter: 58/58
# --
# Training Step: 2  | total loss: 3.92082 | time: 0.030s
# | RMSProp | epoch: 002 | loss: 3.92082 -- iter: 58/58
# --
# Training Step: 3  | total loss: 4.27760 | time: 0.028s
# | RMSProp | epoch: 003 | loss: 4.27760 -- iter: 58/58
# --
# Training Step: 4  | total loss: 4.33673 | time: 0.028s
# | RMSProp | epoch: 004 | loss: 4.33673 -- iter: 58/58
# --
# Training Step: 5  | total loss: 4.35013 | time: 0.028s
# | RMSProp | epoch: 005 | loss: 4.35013 -- iter: 58/58
# --
# Training Step: 6  | total loss: 4.35412 | time: 0.028s
# | RMSProp | epoch: 006 | loss: 4.35412 -- iter: 58/58
# --
# Training Step: 7  | total loss: 4.35580 | time: 0.028s
# | RMSProp | epoch: 007 | loss: 4.35580 -- iter: 58/58
# --
# Training Step: 8  | total loss: 4.35553 | time: 0.027s
# | RMSProp | epoch: 008 | loss: 4.35553 -- iter: 58/58
# --
# Training Step: 9  | total loss: 4.35591 | time: 0.027s
# | RMSProp | epoch: 009 | loss: 4.35591 -- iter: 58/58
# --
# Training Step: 10  | total loss: 4.35638 | time: 0.026s
# | RMSProp | epoch: 010 | loss: 4.35638 -- iter: 58/58
# --
# Training Step: 11  | total loss: 4.35642 | time: 0.027s
# | RMSProp | epoch: 011 | loss: 4.35642 -- iter: 58/58
# --
# Training Step: 12  | total loss: 4.35642 | time: 0.026s
# | RMSProp | epoch: 012 | loss: 4.35642 -- iter: 58/58
# --
# Training Step: 13  | total loss: 4.35603 | time: 0.027s
# | RMSProp | epoch: 013 | loss: 4.35603 -- iter: 58/58
# --
# Training Step: 14  | total loss: 4.35573 | time: 0.026s
# | RMSProp | epoch: 014 | loss: 4.35573 -- iter: 58/58
# --
# Training Step: 15  | total loss: 4.35589 | time: 0.026s
# | RMSProp | epoch: 015 | loss: 4.35589 -- iter: 58/58
# --
# Training Step: 16  | total loss: 4.35620 | time: 0.026s
# | RMSProp | epoch: 016 | loss: 4.35620 -- iter: 58/58
# --
# Training Step: 17  | total loss: 4.35608 | time: 0.027s
# | RMSProp | epoch: 017 | loss: 4.35608 -- iter: 58/58
# --
# Training Step: 18  | total loss: 4.35607 | time: 0.026s
# | RMSProp | epoch: 018 | loss: 4.35607 -- iter: 58/58
# --
# Training Step: 19  | total loss: 4.35616 | time: 0.026s
# | RMSProp | epoch: 019 | loss: 4.35616 -- iter: 58/58
# --
# Training Step: 20  | total loss: 4.35630 | time: 0.026s
# | RMSProp | epoch: 020 | loss: 4.35630 -- iter: 58/58
# --
# Training Step: 21  | total loss: 4.35625 | time: 0.026s
# | RMSProp | epoch: 021 | loss: 4.35625 -- iter: 58/58
# --
# Training Step: 22  | total loss: 4.35599 | time: 0.025s
# | RMSProp | epoch: 022 | loss: 4.35599 -- iter: 58/58
# --
# Training Step: 23  | total loss: 4.35590 | time: 0.027s
# | RMSProp | epoch: 023 | loss: 4.35590 -- iter: 58/58
# --
# Training Step: 24  | total loss: 4.35573 | time: 0.027s
# | RMSProp | epoch: 024 | loss: 4.35573 -- iter: 58/58
# --
# Training Step: 25  | total loss: 4.35573 | time: 0.037s
# | RMSProp | epoch: 025 | loss: 4.35573 -- iter: 58/58
# --
# Training Step: 26  | total loss: 4.35549 | time: 0.026s
# | RMSProp | epoch: 026 | loss: 4.35549 -- iter: 58/58
# --
# Training Step: 27  | total loss: 4.35544 | time: 0.026s
# | RMSProp | epoch: 027 | loss: 4.35544 -- iter: 58/58
# --
# Training Step: 28  | total loss: 4.35514 | time: 0.027s
# | RMSProp | epoch: 028 | loss: 4.35514 -- iter: 58/58
# --
# Training Step: 29  | total loss: 4.35475 | time: 0.026s
# | RMSProp | epoch: 029 | loss: 4.35475 -- iter: 58/58
# --
# Training Step: 30  | total loss: 4.35483 | time: 0.026s
# | RMSProp | epoch: 030 | loss: 4.35483 -- iter: 58/58
# --
# Training Step: 31  | total loss: 4.35493 | time: 0.026s
# | RMSProp | epoch: 031 | loss: 4.35493 -- iter: 58/58
# --
# Training Step: 32  | total loss: 4.35483 | time: 0.026s
# | RMSProp | epoch: 032 | loss: 4.35483 -- iter: 58/58
# --
# Training Step: 33  | total loss: 4.35491 | time: 0.027s
# | RMSProp | epoch: 033 | loss: 4.35491 -- iter: 58/58
# --
# Training Step: 34  | total loss: 4.35466 | time: 0.027s
# | RMSProp | epoch: 034 | loss: 4.35466 -- iter: 58/58
# --
# Training Step: 35  | total loss: 4.35453 | time: 0.026s
# | RMSProp | epoch: 035 | loss: 4.35453 -- iter: 58/58
# --
# Training Step: 36  | total loss: 4.35443 | time: 0.027s
# | RMSProp | epoch: 036 | loss: 4.35443 -- iter: 58/58
# --
# Training Step: 37  | total loss: 4.35433 | time: 0.026s
# | RMSProp | epoch: 037 | loss: 4.35433 -- iter: 58/58
# --
# Training Step: 38  | total loss: 4.35408 | time: 0.026s
# | RMSProp | epoch: 038 | loss: 4.35408 -- iter: 58/58
# --
# Training Step: 39  | total loss: 4.35389 | time: 0.026s
# | RMSProp | epoch: 039 | loss: 4.35389 -- iter: 58/58
# --
# Training Step: 40  | total loss: 4.35377 | time: 0.025s
# | RMSProp | epoch: 040 | loss: 4.35377 -- iter: 58/58
# --
# Training Step: 41  | total loss: 4.35351 | time: 0.027s
# | RMSProp | epoch: 041 | loss: 4.35351 -- iter: 58/58
# --
# Training Step: 42  | total loss: 4.35337 | time: 0.027s
# | RMSProp | epoch: 042 | loss: 4.35337 -- iter: 58/58
# --
# Training Step: 43  | total loss: 4.35313 | time: 0.027s
# | RMSProp | epoch: 043 | loss: 4.35313 -- iter: 58/58
# --
# Training Step: 44  | total loss: 4.35321 | time: 0.026s
# | RMSProp | epoch: 044 | loss: 4.35321 -- iter: 58/58
# --
# Training Step: 45  | total loss: 4.35325 | time: 0.026s
# | RMSProp | epoch: 045 | loss: 4.35325 -- iter: 58/58
# --
# Training Step: 46  | total loss: 4.35317 | time: 0.027s
# | RMSProp | epoch: 046 | loss: 4.35317 -- iter: 58/58
# --
# Training Step: 47  | total loss: 4.35291 | time: 0.026s
# | RMSProp | epoch: 047 | loss: 4.35291 -- iter: 58/58
# --
# Training Step: 48  | total loss: 4.35285 | time: 0.026s
# | RMSProp | epoch: 048 | loss: 4.35285 -- iter: 58/58
# --
# Training Step: 49  | total loss: 4.35280 | time: 0.025s
# | RMSProp | epoch: 049 | loss: 4.35280 -- iter: 58/58
# --
# Training Step: 50  | total loss: 4.35242 | time: 0.026s
# | RMSProp | epoch: 050 | loss: 4.35242 -- iter: 58/58
# --
# Training Step: 51  | total loss: 4.35220 | time: 0.025s
# | RMSProp | epoch: 051 | loss: 4.35220 -- iter: 58/58
# --
# Training Step: 52  | total loss: 4.35200 | time: 0.025s
# | RMSProp | epoch: 052 | loss: 4.35200 -- iter: 58/58
# --
# Training Step: 53  | total loss: 4.35165 | time: 0.025s
# | RMSProp | epoch: 053 | loss: 4.35165 -- iter: 58/58
# --
# Training Step: 54  | total loss: 4.35144 | time: 0.025s
# | RMSProp | epoch: 054 | loss: 4.35144 -- iter: 58/58
# --
# Training Step: 55  | total loss: 4.35115 | time: 0.025s
# | RMSProp | epoch: 055 | loss: 4.35115 -- iter: 58/58
# --
# Training Step: 56  | total loss: 4.35071 | time: 0.025s
# | RMSProp | epoch: 056 | loss: 4.35071 -- iter: 58/58
# --
# Training Step: 57  | total loss: 4.35047 | time: 0.026s
# | RMSProp | epoch: 057 | loss: 4.35047 -- iter: 58/58
# --
# Training Step: 58  | total loss: 4.35007 | time: 0.025s
# | RMSProp | epoch: 058 | loss: 4.35007 -- iter: 58/58
# --
# Training Step: 59  | total loss: 4.34961 | time: 0.025s
# | RMSProp | epoch: 059 | loss: 4.34961 -- iter: 58/58
# --
# Training Step: 60  | total loss: 4.34931 | time: 0.025s
# | RMSProp | epoch: 060 | loss: 4.34931 -- iter: 58/58
# --
# Training Step: 61  | total loss: 4.34900 | time: 0.025s
# | RMSProp | epoch: 061 | loss: 4.34900 -- iter: 58/58
# --
# Training Step: 62  | total loss: 4.34857 | time: 0.026s
# | RMSProp | epoch: 062 | loss: 4.34857 -- iter: 58/58
# --
# Training Step: 63  | total loss: 4.34805 | time: 0.025s
# | RMSProp | epoch: 063 | loss: 4.34805 -- iter: 58/58
# --
# Training Step: 64  | total loss: 4.34767 | time: 0.025s
# | RMSProp | epoch: 064 | loss: 4.34767 -- iter: 58/58
# --
# Training Step: 65  | total loss: 4.34727 | time: 0.025s
# | RMSProp | epoch: 065 | loss: 4.34727 -- iter: 58/58
# --
# Training Step: 66  | total loss: 4.34684 | time: 0.025s
# | RMSProp | epoch: 066 | loss: 4.34684 -- iter: 58/58
# --
# Training Step: 67  | total loss: 4.34645 | time: 0.025s
# | RMSProp | epoch: 067 | loss: 4.34645 -- iter: 58/58
# --
# Training Step: 68  | total loss: 4.34612 | time: 0.025s
# | RMSProp | epoch: 068 | loss: 4.34612 -- iter: 58/58
# --
# Training Step: 69  | total loss: 4.34583 | time: 0.025s
# | RMSProp | epoch: 069 | loss: 4.34583 -- iter: 58/58
# --
# Training Step: 70  | total loss: 4.34535 | time: 0.024s
# | RMSProp | epoch: 070 | loss: 4.34535 -- iter: 58/58
# --
# Training Step: 71  | total loss: 4.34476 | time: 0.023s
# | RMSProp | epoch: 071 | loss: 4.34476 -- iter: 58/58
# --
# Training Step: 72  | total loss: 4.34443 | time: 0.024s
# | RMSProp | epoch: 072 | loss: 4.34443 -- iter: 58/58
# --
# Training Step: 73  | total loss: 4.34391 | time: 0.024s
# | RMSProp | epoch: 073 | loss: 4.34391 -- iter: 58/58
# --
# Training Step: 74  | total loss: 4.34332 | time: 0.025s
# | RMSProp | epoch: 074 | loss: 4.34332 -- iter: 58/58
# --
# Training Step: 75  | total loss: 4.34289 | time: 0.024s
# | RMSProp | epoch: 075 | loss: 4.34289 -- iter: 58/58
# --
# Training Step: 76  | total loss: 4.34227 | time: 0.025s
# | RMSProp | epoch: 076 | loss: 4.34227 -- iter: 58/58
# --
# Training Step: 77  | total loss: 4.34166 | time: 0.026s
# | RMSProp | epoch: 077 | loss: 4.34166 -- iter: 58/58
# --
# Training Step: 78  | total loss: 4.34103 | time: 0.024s
# | RMSProp | epoch: 078 | loss: 4.34103 -- iter: 58/58
# --
# Training Step: 79  | total loss: 4.34032 | time: 0.024s
# | RMSProp | epoch: 079 | loss: 4.34032 -- iter: 58/58
# --
# Training Step: 80  | total loss: 4.33958 | time: 0.024s
# | RMSProp | epoch: 080 | loss: 4.33958 -- iter: 58/58
# --
# Training Step: 81  | total loss: 4.33885 | time: 0.024s
# | RMSProp | epoch: 081 | loss: 4.33885 -- iter: 58/58
# --
# Training Step: 82  | total loss: 4.33839 | time: 0.024s
# | RMSProp | epoch: 082 | loss: 4.33839 -- iter: 58/58
# --
# Training Step: 83  | total loss: 4.33773 | time: 0.024s
# | RMSProp | epoch: 083 | loss: 4.33773 -- iter: 58/58
# --
# Training Step: 84  | total loss: 4.33711 | time: 0.024s
# | RMSProp | epoch: 084 | loss: 4.33711 -- iter: 58/58
# --
# Training Step: 85  | total loss: 4.33645 | time: 0.024s
# | RMSProp | epoch: 085 | loss: 4.33645 -- iter: 58/58
# --
# Training Step: 86  | total loss: 4.33565 | time: 0.025s
# | RMSProp | epoch: 086 | loss: 4.33565 -- iter: 58/58
# --
# Training Step: 87  | total loss: 4.33492 | time: 0.025s
# | RMSProp | epoch: 087 | loss: 4.33492 -- iter: 58/58
# --
# Training Step: 88  | total loss: 4.33408 | time: 0.025s
# | RMSProp | epoch: 088 | loss: 4.33408 -- iter: 58/58
# --
# Training Step: 89  | total loss: 4.33314 | time: 0.025s
# | RMSProp | epoch: 089 | loss: 4.33314 -- iter: 58/58
# --
# Training Step: 90  | total loss: 4.33230 | time: 0.024s
# | RMSProp | epoch: 090 | loss: 4.33230 -- iter: 58/58
# --
# Training Step: 91  | total loss: 4.33151 | time: 0.025s
# | RMSProp | epoch: 091 | loss: 4.33151 -- iter: 58/58
# --
# Training Step: 92  | total loss: 4.33055 | time: 0.024s
# | RMSProp | epoch: 092 | loss: 4.33055 -- iter: 58/58
# --
# Training Step: 93  | total loss: 4.32965 | time: 0.024s
# | RMSProp | epoch: 093 | loss: 4.32965 -- iter: 58/58
# --
# Training Step: 94  | total loss: 4.32853 | time: 0.024s
# | RMSProp | epoch: 094 | loss: 4.32853 -- iter: 58/58
# --
# Training Step: 95  | total loss: 4.32766 | time: 0.025s
# | RMSProp | epoch: 095 | loss: 4.32766 -- iter: 58/58
# --
# Training Step: 96  | total loss: 4.32654 | time: 0.025s
# | RMSProp | epoch: 096 | loss: 4.32654 -- iter: 58/58
# --
# Training Step: 97  | total loss: 4.32550 | time: 0.025s
# | RMSProp | epoch: 097 | loss: 4.32550 -- iter: 58/58
# --
# Training Step: 98  | total loss: 4.32446 | time: 0.025s
# | RMSProp | epoch: 098 | loss: 4.32446 -- iter: 58/58
# --
# Training Step: 99  | total loss: 4.32342 | time: 0.024s
# | RMSProp | epoch: 099 | loss: 4.32342 -- iter: 58/58
# --
# Training Step: 100  | total loss: 4.32213 | time: 0.025s
# | RMSProp | epoch: 100 | loss: 4.32213 -- iter: 58/58
# --
# Training Step: 101  | total loss: 4.32068 | time: 0.032s
# | RMSProp | epoch: 101 | loss: 4.32068 -- iter: 58/58
# --
# Training Step: 102  | total loss: 4.31938 | time: 0.024s
# | RMSProp | epoch: 102 | loss: 4.31938 -- iter: 58/58
# --
# Training Step: 103  | total loss: 4.31777 | time: 0.030s
# | RMSProp | epoch: 103 | loss: 4.31777 -- iter: 58/58
# --
# Training Step: 104  | total loss: 4.31598 | time: 0.024s
# | RMSProp | epoch: 104 | loss: 4.31598 -- iter: 58/58
# --
# Training Step: 105  | total loss: 4.31419 | time: 0.025s
# | RMSProp | epoch: 105 | loss: 4.31419 -- iter: 58/58
# --
# Training Step: 106  | total loss: 4.31243 | time: 0.024s
# | RMSProp | epoch: 106 | loss: 4.31243 -- iter: 58/58
# --
# Training Step: 107  | total loss: 4.31051 | time: 0.025s
# | RMSProp | epoch: 107 | loss: 4.31051 -- iter: 58/58
# --
# Training Step: 108  | total loss: 4.30859 | time: 0.025s
# | RMSProp | epoch: 108 | loss: 4.30859 -- iter: 58/58
# --
# Training Step: 109  | total loss: 4.30654 | time: 0.024s
# | RMSProp | epoch: 109 | loss: 4.30654 -- iter: 58/58
# --
# Training Step: 110  | total loss: 4.30403 | time: 0.024s
# | RMSProp | epoch: 110 | loss: 4.30403 -- iter: 58/58
# --
# Training Step: 111  | total loss: 4.30105 | time: 0.025s
# | RMSProp | epoch: 111 | loss: 4.30105 -- iter: 58/58
# --
# Training Step: 112  | total loss: 4.29800 | time: 0.024s
# | RMSProp | epoch: 112 | loss: 4.29800 -- iter: 58/58
# --
# Training Step: 113  | total loss: 4.29483 | time: 0.024s
# | RMSProp | epoch: 113 | loss: 4.29483 -- iter: 58/58
# --
# Training Step: 114  | total loss: 4.29171 | time: 0.024s
# | RMSProp | epoch: 114 | loss: 4.29171 -- iter: 58/58
# --
# Training Step: 115  | total loss: 4.28749 | time: 0.025s
# | RMSProp | epoch: 115 | loss: 4.28749 -- iter: 58/58
# --
# Training Step: 116  | total loss: 4.28321 | time: 0.025s
# | RMSProp | epoch: 116 | loss: 4.28321 -- iter: 58/58
# --
# Training Step: 117  | total loss: 4.27800 | time: 0.024s
# | RMSProp | epoch: 117 | loss: 4.27800 -- iter: 58/58
# --
# Training Step: 118  | total loss: 4.26959 | time: 0.024s
# | RMSProp | epoch: 118 | loss: 4.26959 -- iter: 58/58
# --
# Training Step: 119  | total loss: 4.26118 | time: 0.025s
# | RMSProp | epoch: 119 | loss: 4.26118 -- iter: 58/58
# --
# Training Step: 120  | total loss: 4.25030 | time: 0.024s
# | RMSProp | epoch: 120 | loss: 4.25030 -- iter: 58/58
# --
# Training Step: 121  | total loss: 4.23646 | time: 0.024s
# | RMSProp | epoch: 121 | loss: 4.23646 -- iter: 58/58
# --
# Training Step: 122  | total loss: 4.22011 | time: 0.024s
# | RMSProp | epoch: 122 | loss: 4.22011 -- iter: 58/58
# --
# Training Step: 123  | total loss: 4.19848 | time: 0.024s
# | RMSProp | epoch: 123 | loss: 4.19848 -- iter: 58/58
# --
# Training Step: 124  | total loss: 4.17956 | time: 0.024s
# | RMSProp | epoch: 124 | loss: 4.17956 -- iter: 58/58
# --
# Training Step: 125  | total loss: 4.15168 | time: 0.025s
# | RMSProp | epoch: 125 | loss: 4.15168 -- iter: 58/58
# --
# Training Step: 126  | total loss: 4.12572 | time: 0.024s
# | RMSProp | epoch: 126 | loss: 4.12572 -- iter: 58/58
# --
# Training Step: 127  | total loss: 4.09588 | time: 0.025s
# | RMSProp | epoch: 127 | loss: 4.09588 -- iter: 58/58
# --
# Training Step: 128  | total loss: 4.06470 | time: 0.024s
# | RMSProp | epoch: 128 | loss: 4.06470 -- iter: 58/58
# --
# After pruning: 14 notes
# After pruning: 12 notes
# After pruning: 11 notes
# After pruning: 12 notes
# After pruning: 14 notes
# After pruning: 13 notes
# After pruning: 13 notes
# After pruning: 15 notes
# After pruning: 14 notes
# After pruning: 15 notes
# After pruning: 14 notes
# After pruning: 12 notes
# After pruning: 12 notes
# After pruning: 12 notes
# After pruning: 16 notes
# After pruning: 13 notes
# After pruning: 14 notes
# After pruning: 12 notes

# %% [markdown]
# You can play generated sample using any midi player
#
# Under linux I prefer timidity

# %%
# !! timidity midi/deepjazz_on_metheny...128_epochs.midi
